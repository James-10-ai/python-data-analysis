# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\Hp Elitebook\3D Objects\report_2018-2019.csv")

# %%
data.head()
# Out:
#    Overall rank Country or region  Year  Score  GDP per capita  \
# 0           154       Afghanistan  2019  3.203           0.350
# 1           145       Afghanistan  2018  3.632           0.332
# 2           107           Albania  2019  4.719           0.947
# 3           112           Albania  2018  4.586           0.916
# 4            88           Algeria  2019  5.211           1.002
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.517                    0.361                         0.000
# 1           0.537                    0.255                         0.085
# 2           0.848                    0.874                         0.383
# 3           0.817                    0.790                         0.419
# 4           1.160                    0.785                         0.086
#
#    Generosity  Perceptions of corruption
# 0       0.158                      0.025
# 1       0.191                      0.036
# ...

# %%
data.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Year                            0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
data.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Year                              int64
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312 entries, 0 to 311
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  312 non-null    int64
#  1   Country or region             312 non-null    object
#  2   Year                          312 non-null    int64
#  3   Score                         312 non-null    float64
#  4   GDP per capita                312 non-null    float64
#  5   Social support                312 non-null    float64
#  6   Healthy life expectancy       312 non-null    float64
#  7   Freedom to make life choices  312 non-null    float64
#  8   Generosity                    312 non-null    float64
#  9   Perceptions of corruption     312 non-null    float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 24.5+ KB

# %%
data.describe()
# Out:
#        Overall rank         Year       Score  GDP per capita  Social support  \
# count    312.000000   312.000000  312.000000      312.000000      312.000000
# mean      78.500000  2018.500000    5.391506        0.898298        1.211026
# std       45.104737     0.500803    1.114631        0.394592        0.300310
# min        1.000000  2018.000000    2.853000        0.000000        0.000000
# 25%       39.750000  2018.000000    4.514250        0.609500        1.055750
# 50%       78.500000  2018.500000    5.379500        0.960000        1.265500
# 75%      117.250000  2019.000000    6.176000        1.219500        1.457500
# max      156.000000  2019.000000    7.769000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               312.000000                    312.000000  312.000000
# mean                  0.661295                      0.423538    0.182926
# ...

# %%
df = data.groupby('Year').sum()
# Out:
# C:\Users\Hp Elitebook\AppData\Local\Temp\ipykernel_1056\195408793.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = data.groupby('Year').sum()

# %%
df.head()
# Out:
#       Overall rank    Score  GDP per capita  Social support  \
# Year
# 2018         12246  838.643         139.066         189.265
# 2019         12246  843.507         141.203         188.575
#
#       Healthy life expectancy  Freedom to make life choices  Generosity  \
# Year
# 2018                   93.186                        70.903      28.237
# 2019                  113.138                        61.241      28.836
#
#       Perceptions of corruption
# Year
# 2018                     17.542
# 2019                     17.254

# %% [markdown]
# # Country with highest life expectancy

# %%
GDP = df.groupby('GDP per capita')

# %%
df1 = data.sort_values(by='Country or region')

# %%
df1.head()
# Out:
#    Overall rank Country or region  Year  Score  GDP per capita  \
# 0           154       Afghanistan  2019  3.203           0.350
# 1           145       Afghanistan  2018  3.632           0.332
# 2           107           Albania  2019  4.719           0.947
# 3           112           Albania  2018  4.586           0.916
# 4            88           Algeria  2019  5.211           1.002
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.517                    0.361                         0.000
# 1           0.537                    0.255                         0.085
# 2           0.848                    0.874                         0.383
# 3           0.817                    0.790                         0.419
# 4           1.160                    0.785                         0.086
#
#    Generosity  Perceptions of corruption
# 0       0.158                      0.025
# 1       0.191                      0.036
# ...

# %%
df2 = df1.sort_values(by='GDP per capita').head()

# %%
df2['result'] = df2['GDP per capita']* df2['Healthy life expectancy']

# %%
df2
# Out:
#      Overall rank         Country or region  Year  Score  GDP per capita  \
# 251            98                   Somalia  2018  4.982           0.000
# 250           112                   Somalia  2019  4.668           0.000
# 51            155  Central African Republic  2018  3.083           0.024
# 50            155  Central African Republic  2019  3.083           0.026
# 42            145                   Burundi  2019  3.775           0.046
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 251           0.712                    0.115                         0.674
# 250           0.698                    0.268                         0.559
# 51            0.000                    0.010                         0.305
# 50            0.000                    0.105                         0.225
# 42            0.447                    0.380                         0.220
#
#      Generosity  Perceptions of corruption   result
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
plt.figure(figsize=(30,10))
sns.barplot(x='Country or region', y='GDP per capita', data=data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.barplot(x='Country or region', y= 'Healthy life expectancy', data=data)
plt.xlabel('Country or region')
plt.xticks(rotation=90)
plt.ylabel('Health life expectancy')
plt.title('Country vs Health life expectancy')
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.barplot(x='Country or region', y= 'Social support', data=data)
plt.xlabel('Country or region')
plt.xticks(rotation=90)
plt.ylabel('Social support')
plt.title('Country vs Social support')
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.barplot(x='Country or region', y= 'Perceptions of corruption', data=data)
plt.xlabel('Country or region')
plt.xticks(rotation=90)
plt.ylabel('Perceptions of corruption')
plt.title('Country vs Perceptions of corruption')
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.barplot(x='Country or region', y= 'Freedom to make life choices', data=data)
plt.xlabel('Freedom to make life choices')
plt.xticks(rotation=90)
plt.ylabel('result')
plt.title('Country vs Freedom to make life choices')
plt.show()

# %%
plt.figure(figsize=(8,6))
size = data.groupby(['Year'])['Score'].value_counts()
plt.pie(size, labels=size.index, autopct = '%1.1f%%')
plt.title('Pie plot for Year')
plt.show()

# %%
#correlation bewtween variables

# %%
sns.heatmap(data.corr(), annot = True)
# Out:
# C:\Users\Hp Elitebook\AppData\Local\Temp\ipykernel_1056\1679999493.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot = True)
# <Axes: >

# %%
#Correlation between specific variables

# %%
correlation_matrix = data['Perceptions of corruption'].corr(data['GDP per capita'])
print('Correlation_matrix:', correlation_matrix)
# Out:
# Correlation_matrix: 0.3109508763185201

# %%
#Prediction model

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 data.index()
#
# TypeError: 'RangeIndex' object is not callable

# %%
#Independent and Dependent variables
X=data[['Score','Social support','Healthy life expectancy','Freedom to make life choices', 'Generosity','Perceptions of corruption']]
y= data['GDP per capita']

#Train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=100)

#Design linear model
model = LinearRegression()
model.fit(X_train, y_train)
#Predictor model
y_pred = model.predict(X_test)

#Visualize the predictor model
plt.figure(figsize=(8,6))
plt.scatter(y_test,y_pred)
plt.plot([min(y_test), max(y_test)],[min(y_test), max(y_test)], color ='red', linestyle='--')
plt.title('LINEAR VISUALIZATION MODEL')
plt.xlabel('Country')
plt.xticks(rotation=90)
plt.ylabel('GDP per capita')
plt.show()

# %%
#Predict GDP of a specific Country

# %%
new_gdp =[[3.5,0.651,0.853,0.135,0.215,0.078]]
new_pred_gdp = model.predict(X_test)
print('new_pred_gdp:',new_pred_gdp)
# Out:
# new_pred_gdp: [0.45695423 0.93924685 0.29554963 0.29554415 1.38973369 1.20977213
#  0.52124608 1.23807062 0.52145428 0.41871443 1.00348935 1.06030371
#  1.02031005 1.06442213 1.28214385 1.17077082 0.53111856 1.18783745
#  0.38219653 0.67388912 0.96978783 0.99153313 0.83275114 1.04052321
#  1.17673953 1.11486604 0.40598574 0.55899337 1.24366378 0.38619923
#  1.23900347 1.32247927 1.01649499 0.54940516 1.11508787 0.71361934
#  1.13316801 0.45995071 0.81749848 1.39902603 0.23778982 0.93915935
#  0.48397155 1.1021983  1.45146127 0.95462107 1.36398863 1.29627479
#  1.05763106 1.4471592  1.03279144 1.23320515 0.90338954 1.43416998
#  1.02176552 0.92514911 0.79832875 0.98985857 0.80579269 1.4379124
#  0.29484977 0.20787598 0.89653934]

# %%
#Model evaluation

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
#Evaluate model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('mean squared error:', mse)
print('root mean squared error:', rmse)
print('mean absolute error:', mae)
print('r-squared:', r2)
# Out:
# mean squared error: 0.03376513632378417
# root mean squared error: 0.1837529219462487
# mean absolute error: 0.1492333077432935
# r-squared: 0.8016938527259341

# %%
#Model Interpretation

# %%
coefficients = model.coef_
intercept = model.intercept_
print('coefficients:', coefficients)
print('intercept:', intercept)
# Out:
# coefficients: [ 0.12638014  0.17971888  0.69566701 -0.12447233 -0.41644272  0.26719132]
# intercept: -0.3568653440765378
